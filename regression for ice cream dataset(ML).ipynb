# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Ice_cream selling data.csv')

# %%
dataset
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
x
# Out:
# array([[-4.66226268],
#        [-4.31655945],
#        [-4.21398476],
#        [-3.94966109],
#        [-3.57855372],
#        [-3.4557117 ],
#        [-3.10844012],
#        [-3.08130332],
#        [-2.67246083],
#        [-2.65228679],
#        [-2.65149803],
#        [-2.288264  ],
#        [-2.11186969],
#        [-1.81893761],
#        [-1.66034773],
#        [-1.32637898],
#        [-1.17312327],
#        [-0.77333004],
#        [-0.6737528 ],
#        [-0.14963487],
#        [-0.0361565 ],
#        [-0.03389529],
#        [ 0.0086077 ],
#        [ 0.14924457],
#        [ 0.68878091],
#        [ 0.69359887],
#        [ 0.87490503],
#        [ 1.02418081],
#        [ 1.24071162],
#        [ 1.35981267],
#        [ 1.74000001],
#        [ 1.85055193],
#        [ 1.99931037],
#        [ 2.0751006 ],
#        [ 2.31859124],
#        [ 2.471946  ],
#        [ 2.78483646],
#        [ 2.83176021],
#        [ 2.95993209],
#        [ 3.02087431],
#        [ 3.21136614],
# ...

# %%
y
# Out:
# array([41.84298632, 34.66111954, 39.38300088, 37.53984488, 32.28453119,
#        30.00113848, 22.63540128, 25.36502221, 19.22697005, 20.27967918,
#        13.2758285 , 18.12399121, 11.21829447, 10.01286785, 12.61518115,
#        10.95773134,  6.68912264,  9.39296866,  5.21016262,  4.67364254,
#         0.32862552,  0.89760319,  3.16560001,  1.93141603,  2.57678224,
#         4.62568946,  0.78997365,  2.31380636,  1.29236081,  0.95311531,
#         3.78257014,  4.8579878 ,  8.94382321,  8.17073494,  7.41209403,
#        10.33663062, 15.99661997, 12.56823739, 21.34291574, 20.11441346,
#        22.8394055 , 16.98327874, 25.14208223, 26.10474041, 28.91218793,
#        17.84395652, 34.53074274, 27.69838335, 41.51482194])

# %% [markdown]
# ## simple linear regression

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('tempreture vs sales (Training set)')
plt.show()

# %% [markdown]
# ## polynomial regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=6)
x_poly=poly_reg.fit_transform(x)
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('temperature vs sales (Training set)')
plt.show()

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'blue')
plt.title('temperature vs sales (Polynomial Regression)')
plt.show()

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((-1, 1))
plt.scatter(x, y, color = 'red')
plt.plot(x_grid, lin_reg_2.predict(poly_reg.fit_transform(x_grid)), color = 'blue')
plt.title('temperature vs sales (Polynomial Regression)')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3160\2271232850.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)

# %% [markdown]
# ## split dataset

# %%
low_temp=dataset[dataset['Temperature (°C)']<0]

# %%
low_temp
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
high_temp=dataset[dataset['Temperature (°C)']>0]

# %%
high_temp
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 22          0.008608                 3.165600
# 23          0.149245                 1.931416
# 24          0.688781                 2.576782
# 25          0.693599                 4.625689
# 26          0.874905                 0.789974
# 27          1.024181                 2.313806
# 28          1.240712                 1.292361
# 29          1.359813                 0.953115
# 30          1.740000                 3.782570
# 31          1.850552                 4.857988
# 32          1.999310                 8.943823
# 33          2.075101                 8.170735
# 34          2.318591                 7.412094
# 35          2.471946                10.336631
# 36          2.784836                15.996620
# 37          2.831760                12.568237
# 38          2.959932                21.342916
# 39          3.020874                20.114413
# 40          3.211366                22.839406
# ...

# %%
low_x=low_temp.iloc[:, :-1].values
low_y=low_temp.iloc[:, -1].values

# %%
high_x=high_temp.iloc[:,:-1].values
high_y=high_temp.iloc[:,-1].values

# %%
high_x
# Out:
# array([[0.0086077 ],
#        [0.14924457],
#        [0.68878091],
#        [0.69359887],
#        [0.87490503],
#        [1.02418081],
#        [1.24071162],
#        [1.35981267],
#        [1.74000001],
#        [1.85055193],
#        [1.99931037],
#        [2.0751006 ],
#        [2.31859124],
#        [2.471946  ],
#        [2.78483646],
#        [2.83176021],
#        [2.95993209],
#        [3.02087431],
#        [3.21136614],
#        [3.27004407],
#        [3.31607252],
#        [3.33593241],
#        [3.61077848],
#        [3.70405744],
#        [4.13086796],
#        [4.13353379],
#        [4.89903151]])

# %%
high_y
# Out:
# array([ 3.16560001,  1.93141603,  2.57678224,  4.62568946,  0.78997365,
#         2.31380636,  1.29236081,  0.95311531,  3.78257014,  4.8579878 ,
#         8.94382321,  8.17073494,  7.41209403, 10.33663062, 15.99661997,
#        12.56823739, 21.34291574, 20.11441346, 22.8394055 , 16.98327874,
#        25.14208223, 26.10474041, 28.91218793, 17.84395652, 34.53074274,
#        27.69838335, 41.51482194])

# %%
low_x
# Out:
# array([[-4.66226268],
#        [-4.31655945],
#        [-4.21398476],
#        [-3.94966109],
#        [-3.57855372],
#        [-3.4557117 ],
#        [-3.10844012],
#        [-3.08130332],
#        [-2.67246083],
#        [-2.65228679],
#        [-2.65149803],
#        [-2.288264  ],
#        [-2.11186969],
#        [-1.81893761],
#        [-1.66034773],
#        [-1.32637898],
#        [-1.17312327],
#        [-0.77333004],
#        [-0.6737528 ],
#        [-0.14963487],
#        [-0.0361565 ],
#        [-0.03389529]])

# %%
low_y
# Out:
# array([41.84298632, 34.66111954, 39.38300088, 37.53984488, 32.28453119,
#        30.00113848, 22.63540128, 25.36502221, 19.22697005, 20.27967918,
#        13.2758285 , 18.12399121, 11.21829447, 10.01286785, 12.61518115,
#        10.95773134,  6.68912264,  9.39296866,  5.21016262,  4.67364254,
#         0.32862552,  0.89760319])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=6)
x_poly=poly_reg.fit_transform(x)
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
x_grid = np.arange(min(low_x), max(low_x), 0.1)
x_grid = x_grid.reshape((-1, 1))
plt.scatter(low_x,low_y, color = 'red')
plt.plot(x_grid, lin_reg_2.predict(poly_reg.fit_transform(x_grid)), color = 'blue')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3160\3677418072.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(low_x), max(low_x), 0.1)

# %%
x_grid=np.arange(min(high_x),max(high_x),0.1)
x_grid= x_grid.reshape((-1, 1))
plt.scatter(high_x,high_y, color = 'red')
plt.plot(x_grid, lin_reg_2.predict(poly_reg.fit_transform(x_grid)), color = 'blue')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3160\721947105.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(high_x),max(high_x),0.1)
